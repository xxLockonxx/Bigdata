# %%
"""
날짜 : 2020/08/10
이름 : 이성진
내용 : Matplotlib(시각화 패키지) 실습하기
"""
# Out:
# '\n날짜 : 2020/08/10\n이름 : 이성진\n내용 : Matplotlib(시각화 패키지) 실습하기\n'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#기본 플로차트
plt.title('plot1')
plt.plot([1,3,4,9,10,7])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# x축 지정
plt.title('plot2')
plt.plot([10,20,30,40,50,60],[1,3,4,9,10,7])
plt.show()

# %%
# 차트 스타일
plt.title('plot3')
plt.plot([10,20,30,40,50,60],[1,3,4,9,10,7], 'go:')
plt.show()

# %%
# 차트 스타일
plt.title('plot3')
plt.plot([10,20,30,40,50,60],[1,3,4,9,10,7], 'rs')
plt.grid(True)
plt.show()

# %%
#멀티 라인차트
data = np.arange(0, 5, 0.2)
data

plt.title('plot4')
plt.plot(data, data, 'r--')
plt.plot(data, data**2, 'b--') # **2 거듭제곱
plt.plot(data, data**3, 'g--')
plt.show()

# %%
#막대그래프
plt.title('plot5')
plt.bar(['apple','banan','orange','grape','berry'],
        [5, 3, 7, 9, 8])
plt.xlabel('fruit')
plt.ylabel('count')
plt.show()

# %%
#히스토그램
data1 = np.random.rand(1000)
data2 = np.random.randn(1000)

plt.title('hist1')
plt.hist(data1, edgecolor='black')
plt.show()

plt.title('hist2')
plt.hist(data2, edgecolor='black')
plt.show()

# %%
#산점도
x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)

plt.title('scatter')
plt.scatter(x, y)
plt.show()
